# %%
import pandas as pd
import numpy as np

# %%
## part a:

# %%
vc = pd.read_csv("Desktop/Vehicle.csv")

# %%
df = pd.DataFrame(vc);
df
# Out:
#      COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  RADIUS_RATIO  \
# 0             95           48                    83           178
# 1             91           41                    84           141
# 2            104           50                   106           209
# 3             93           41                    82           159
# 4             85           44                    70           205
# ..           ...          ...                   ...           ...
# 841           93           39                    87           183
# 842           89           46                    84           163
# 843          106           54                   101           222
# 844           86           36                    78           146
# 845           85           36                    66           123
#
#      PR.AXIS_ASPECT_RATIO  MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# 0                      72                       10            162
# 1                      57                        9            149
# 2                      66                       10            207
# 3                      63                        9            144
# 4                     103                       52            149
# ..                    ...                      ...            ...
# 841                    64                        8            169
# 842                    66                       11            159
# 843                    67                       12            222
# 844                    58                        7            135
# 845                    55                        5            120
#
#      ELONGATEDNESS  PR.AXIS_RECTANGULARITY  MAX.LENGTH_RECTANGULARITY  \
# 0               42                      20                        159
# 1               45                      19                        143
# 2               32                      23                        158
# 3               46                      19                        143
# 4               45                      19                        144
# ..             ...                     ...                        ...
# 841             40                      20                        134
# 842             43                      20                        159
# 843             30                      25                        173
# 844             50                      18                        124
# 845             56                      17                        128
#
#      SCALED_VARIANCE_MAJOR  SCALED_VARIANCE_MINOR  SCALED_RADIUS_OF_GYRATION  \
# 0                      176                    379                        184
# 1                      170                    330                        158
# 2                      223                    635                        220
# 3                      160                    309                        127
# 4                      241                    325                        188
# ..                     ...                    ...                        ...
# 841                    200                    422                        149
# 842                    173                    368                        176
# 843                    228                    721                        200
# 844                    155                    270                        148
# 845                    140                    212                        131
#
#      SKEWNESS_ABOUT_MAJOR  SKEWNESS_ABOUT_MINOR  KURTOSIS_ABOUT_MAJOR  \
# 0                      70                     6                    16
# 1                      72                     9                    14
# 2                      73                    14                     9
# 3                      63                     6                    10
# 4                     127                     9                    11
# ..                    ...                   ...                   ...
# 841                    72                     7                    25
# 842                    72                     1                    20
# 843                    70                     3                     4
# 844                    66                     0                    25
# 845                    73                     1                    18
#
#      KURTOSIS_ABOUT_MINOR  HOLLOWS_RATIO Class
# 0                     187            197   van
# 1                     189            199   van
# 2                     188            196  saab
# 3                     199            207   van
# 4                     180            183   bus
# ..                    ...            ...   ...
# 841                   188            195  saab
# 842                   186            197   van
# 843                   187            201  saab
# 844                   190            195  saab
# 845                   186            190   van
#
# [846 rows x 19 columns]

# %%
## part b:

# %%
## checking missing values:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 846 entries, 0 to 845
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   COMPACTNESS                846 non-null    int64
#  1   CIRCULARITY                846 non-null    int64
#  2   DISTANCE_CIRCULARITY       846 non-null    int64
#  3   RADIUS_RATIO               846 non-null    int64
#  4   PR.AXIS_ASPECT_RATIO       846 non-null    int64
#  5   MAX.LENGTH_ASPECT_RATIO    846 non-null    int64
#  6   SCATTER_RATIO              846 non-null    int64
#  7   ELONGATEDNESS              846 non-null    int64
#  8   PR.AXIS_RECTANGULARITY     846 non-null    int64
#  9   MAX.LENGTH_RECTANGULARITY  846 non-null    int64
#  10  SCALED_VARIANCE_MAJOR      846 non-null    int64
#  11  SCALED_VARIANCE_MINOR      846 non-null    int64
#  12  SCALED_RADIUS_OF_GYRATION  846 non-null    int64
#  13  SKEWNESS_ABOUT_MAJOR       846 non-null    int64
#  14  SKEWNESS_ABOUT_MINOR       846 non-null    int64
#  15  KURTOSIS_ABOUT_MAJOR       846 non-null    int64
#  16  KURTOSIS_ABOUT_MINOR       846 non-null    int64
#  17  HOLLOWS_RATIO              846 non-null    int64
#  18  Class                      846 non-null    object
# dtypes: int64(18), object(1)
# memory usage: 125.7+ KB

# %%
## normalizing integer values:

# %%
from sklearn import preprocessing

# %%
df_scaleN = preprocessing.normalize(df[['COMPACTNESS', 'CIRCULARITY', 'DISTANCE_CIRCULARITY', 'RADIUS_RATIO', 'PR.AXIS_ASPECT_RATIO', 'MAX.LENGTH_ASPECT_RATIO', 'SCATTER_RATIO', 'ELONGATEDNESS', 'PR.AXIS_RECTANGULARITY', 'MAX.LENGTH_RECTANGULARITY', 'SCALED_VARIANCE_MAJOR', 'SCALED_VARIANCE_MINOR', 'SCALED_RADIUS_OF_GYRATION', 'SKEWNESS_ABOUT_MAJOR', 'SKEWNESS_ABOUT_MINOR', 'KURTOSIS_ABOUT_MAJOR', 'KURTOSIS_ABOUT_MINOR', 'HOLLOWS_RATIO']])
df_scaleN = pd.DataFrame(df_scaleN);
df_scaleN['Class'] = df['Class']
df_scaleN.columns = ['COMPACTNESS', 'CIRCULARITY', 'DISTANCE_CIRCULARITY', 'RADIUS_RATIO', 'PR.AXIS_ASPECT_RATIO', 'MAX.LENGTH_ASPECT_RATIO', 'SCATTER_RATIO', 'ELONGATEDNESS', 'PR.AXIS_RECTANGULARITY', 'MAX.LENGTH_RECTANGULARITY', 'SCALED_VARIANCE_MAJOR', 'SCALED_VARIANCE_MINOR', 'SCALED_RADIUS_OF_GYRATION', 'SKEWNESS_ABOUT_MAJOR', 'SKEWNESS_ABOUT_MINOR', 'KURTOSIS_ABOUT_MAJOR', 'KURTOSIS_ABOUT_MINOR', 'HOLLOWS_RATIO', 'Class'] 
df_scaleN
# Out:
#      COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  RADIUS_RATIO  \
# 0       0.150904     0.076246              0.131843      0.282747
# 1       0.158697     0.071501              0.146489      0.245893
# 2       0.122330     0.058812              0.124682      0.245836
# 3       0.166015     0.073190              0.146379      0.283833
# 4       0.135075     0.069921              0.111238      0.325770
# ..           ...          ...                   ...           ...
# 841     0.142922     0.059935              0.133701      0.281233
# 842     0.145091     0.074991              0.136940      0.265729
# 843     0.114897     0.058532              0.109477      0.240633
# 844     0.164335     0.068791              0.149048      0.278987
# 845     0.179869     0.076180              0.139663      0.260280
#
#      PR.AXIS_ASPECT_RATIO  MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# 0                0.114370                 0.015885       0.257332
# 1                0.099403                 0.015695       0.259844
# 2                0.077632                 0.011762       0.243483
# 3                0.112462                 0.016066       0.257056
# 4                0.163679                 0.082634       0.236779
# ..                    ...                      ...            ...
# 841              0.098355                 0.012294       0.259718
# 842              0.107596                 0.017933       0.259208
# 843              0.072624                 0.013007       0.240633
# 844              0.110831                 0.013376       0.257968
# 845              0.116386                 0.010581       0.253932
#
#      ELONGATEDNESS  PR.AXIS_RECTANGULARITY  MAX.LENGTH_RECTANGULARITY  \
# 0         0.066716                0.031769                   0.252566
# 1         0.078476                0.033134                   0.249380
# 2         0.037640                0.027054                   0.185847
# 3         0.082115                0.033917                   0.255271
# 4         0.071510                0.030193                   0.228833
# ..             ...                     ...                        ...
# 841       0.061472                0.030736                   0.205930
# 842       0.070100                0.032605                   0.259208
# 843       0.032518                0.027098                   0.187520
# 844       0.095544                0.034396                   0.236948
# 845       0.118502                0.035974                   0.270861
#
#      SCALED_VARIANCE_MAJOR  SCALED_VARIANCE_MINOR  SCALED_RADIUS_OF_GYRATION  \
# 0                 0.279570               0.602029                   0.292278
# 1                 0.296466               0.575493                   0.275539
# 2                 0.262303               0.746917                   0.258774
# 3                 0.285618               0.551599                   0.226709
# 4                 0.382978               0.516464                   0.298755
# ..                     ...                    ...                        ...
# 841               0.307359               0.648527                   0.228982
# 842               0.282031               0.599927                   0.286922
# 843               0.247137               0.781516                   0.216787
# 844               0.296185               0.515936                   0.282809
# 845               0.296254               0.448613                   0.277209
#
#      SKEWNESS_ABOUT_MAJOR  SKEWNESS_ABOUT_MINOR  KURTOSIS_ABOUT_MAJOR  \
# 0                0.111193              0.009531              0.025415
# 1                0.125562              0.015695              0.024415
# 2                0.085866              0.016467              0.010586
# 3                0.112462              0.010711              0.017851
# 4                0.201818              0.014302              0.017480
# ..                    ...                   ...                   ...
# 841              0.110649              0.010758              0.038420
# 842              0.117377              0.001630              0.032605
# 843              0.075875              0.003252              0.004336
# 844              0.126118              0.000000              0.047772
# 845              0.154475              0.002116              0.038090
#
#      KURTOSIS_ABOUT_MINOR  HOLLOWS_RATIO Class
# 0                0.297043       0.312928   van
# 1                0.329601       0.347040   van
# 2                0.221134       0.230544  saab
# 3                0.355237       0.369518   van
# 4                0.286042       0.290809   bus
# ..                    ...            ...   ...
# 841              0.288917       0.299675  saab
# 842              0.303224       0.321157   van
# 843              0.202696       0.217871  saab
# 844              0.363066       0.372620  saab
# 845              0.393595       0.402059   van
#
# [846 rows x 19 columns]

# %%
## encoding categorical variable:

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
encoder = OrdinalEncoder()

# %%
df_ready['Class'] = encoder.fit_transform(df_scaleN[['Class']])
df_ready[['COMPACTNESS', 'CIRCULARITY', 'DISTANCE_CIRCULARITY', 'RADIUS_RATIO', 'PR.AXIS_ASPECT_RATIO', 'MAX.LENGTH_ASPECT_RATIO', 'SCATTER_RATIO', 'ELONGATEDNESS', 'PR.AXIS_RECTANGULARITY', 'MAX.LENGTH_RECTANGULARITY', 'SCALED_VARIANCE_MAJOR', 'SCALED_VARIANCE_MINOR', 'SCALED_RADIUS_OF_GYRATION', 'SKEWNESS_ABOUT_MAJOR', 'SKEWNESS_ABOUT_MINOR', 'KURTOSIS_ABOUT_MAJOR', 'KURTOSIS_ABOUT_MINOR', 'HOLLOWS_RATIO']] = df_scaleN[['COMPACTNESS', 'CIRCULARITY', 'DISTANCE_CIRCULARITY', 'RADIUS_RATIO', 'PR.AXIS_ASPECT_RATIO', 'MAX.LENGTH_ASPECT_RATIO', 'SCATTER_RATIO', 'ELONGATEDNESS', 'PR.AXIS_RECTANGULARITY', 'MAX.LENGTH_RECTANGULARITY', 'SCALED_VARIANCE_MAJOR', 'SCALED_VARIANCE_MINOR', 'SCALED_RADIUS_OF_GYRATION', 'SKEWNESS_ABOUT_MAJOR', 'SKEWNESS_ABOUT_MINOR', 'KURTOSIS_ABOUT_MAJOR', 'KURTOSIS_ABOUT_MINOR', 'HOLLOWS_RATIO']]
df_ready = pd.DataFrame(df_ready);
df_ready.columns = ['COMPACTNESS', 'CIRCULARITY', 'DISTANCE_CIRCULARITY', 'RADIUS_RATIO', 'PR.AXIS_ASPECT_RATIO', 'MAX.LENGTH_ASPECT_RATIO', 'SCATTER_RATIO', 'ELONGATEDNESS', 'PR.AXIS_RECTANGULARITY', 'MAX.LENGTH_RECTANGULARITY', 'SCALED_VARIANCE_MAJOR', 'SCALED_VARIANCE_MINOR', 'SCALED_RADIUS_OF_GYRATION', 'SKEWNESS_ABOUT_MAJOR', 'SKEWNESS_ABOUT_MINOR', 'KURTOSIS_ABOUT_MAJOR', 'KURTOSIS_ABOUT_MINOR', 'HOLLOWS_RATIO', 'Class'] 
df_ready
# Out:
#      COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  RADIUS_RATIO  \
# 0       0.150904     0.076246              0.131843      0.282747
# 1       0.158697     0.071501              0.146489      0.245893
# 2       0.122330     0.058812              0.124682      0.245836
# 3       0.166015     0.073190              0.146379      0.283833
# 4       0.135075     0.069921              0.111238      0.325770
# ..           ...          ...                   ...           ...
# 841     0.142922     0.059935              0.133701      0.281233
# 842     0.145091     0.074991              0.136940      0.265729
# 843     0.114897     0.058532              0.109477      0.240633
# 844     0.164335     0.068791              0.149048      0.278987
# 845     0.179869     0.076180              0.139663      0.260280
#
#      PR.AXIS_ASPECT_RATIO  MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# 0                0.114370                 0.015885       0.257332
# 1                0.099403                 0.015695       0.259844
# 2                0.077632                 0.011762       0.243483
# 3                0.112462                 0.016066       0.257056
# 4                0.163679                 0.082634       0.236779
# ..                    ...                      ...            ...
# 841              0.098355                 0.012294       0.259718
# 842              0.107596                 0.017933       0.259208
# 843              0.072624                 0.013007       0.240633
# 844              0.110831                 0.013376       0.257968
# 845              0.116386                 0.010581       0.253932
#
#      ELONGATEDNESS  PR.AXIS_RECTANGULARITY  MAX.LENGTH_RECTANGULARITY  \
# 0         0.066716                0.031769                   0.252566
# 1         0.078476                0.033134                   0.249380
# 2         0.037640                0.027054                   0.185847
# 3         0.082115                0.033917                   0.255271
# 4         0.071510                0.030193                   0.228833
# ..             ...                     ...                        ...
# 841       0.061472                0.030736                   0.205930
# 842       0.070100                0.032605                   0.259208
# 843       0.032518                0.027098                   0.187520
# 844       0.095544                0.034396                   0.236948
# 845       0.118502                0.035974                   0.270861
#
#      SCALED_VARIANCE_MAJOR  SCALED_VARIANCE_MINOR  SCALED_RADIUS_OF_GYRATION  \
# 0                 0.279570               0.602029                   0.292278
# 1                 0.296466               0.575493                   0.275539
# 2                 0.262303               0.746917                   0.258774
# 3                 0.285618               0.551599                   0.226709
# 4                 0.382978               0.516464                   0.298755
# ..                     ...                    ...                        ...
# 841               0.307359               0.648527                   0.228982
# 842               0.282031               0.599927                   0.286922
# 843               0.247137               0.781516                   0.216787
# 844               0.296185               0.515936                   0.282809
# 845               0.296254               0.448613                   0.277209
#
#      SKEWNESS_ABOUT_MAJOR  SKEWNESS_ABOUT_MINOR  KURTOSIS_ABOUT_MAJOR  \
# 0                0.111193              0.009531              0.025415
# 1                0.125562              0.015695              0.024415
# 2                0.085866              0.016467              0.010586
# 3                0.112462              0.010711              0.017851
# 4                0.201818              0.014302              0.017480
# ..                    ...                   ...                   ...
# 841              0.110649              0.010758              0.038420
# 842              0.117377              0.001630              0.032605
# 843              0.075875              0.003252              0.004336
# 844              0.126118              0.000000              0.047772
# 845              0.154475              0.002116              0.038090
#
#      KURTOSIS_ABOUT_MINOR  HOLLOWS_RATIO  Class
# 0                0.297043       0.312928    3.0
# 1                0.329601       0.347040    3.0
# 2                0.221134       0.230544    2.0
# 3                0.355237       0.369518    3.0
# 4                0.286042       0.290809    0.0
# ..                    ...            ...    ...
# 841              0.288917       0.299675    2.0
# 842              0.303224       0.321157    3.0
# 843              0.202696       0.217871    2.0
# 844              0.363066       0.372620    2.0
# 845              0.393595       0.402059    3.0
#
# [846 rows x 19 columns]

# %%
## part c:

# %%
import seaborn as sns

# %%
df_ready.corr()
# Out:
#                            COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  \
# COMPACTNESS                   1.000000     0.739408              0.424366
# CIRCULARITY                   0.739408     1.000000              0.362070
# DISTANCE_CIRCULARITY          0.424366     0.362070              1.000000
# RADIUS_RATIO                  0.400849     0.195790              0.374063
# PR.AXIS_ASPECT_RATIO          0.759390     0.669136              0.345177
# MAX.LENGTH_ASPECT_RATIO       0.104847     0.182644              0.212226
# SCATTER_RATIO                 0.640513     0.591633              0.463832
# ELONGATEDNESS                 0.937812     0.800523              0.336962
# PR.AXIS_RECTANGULARITY        0.917570     0.795252              0.408667
# MAX.LENGTH_RECTANGULARITY     0.865361     0.952353              0.428002
# SCALED_VARIANCE_MAJOR         0.703115     0.601254              0.376476
# SCALED_VARIANCE_MINOR        -0.934506    -0.831637             -0.400163
# SCALED_RADIUS_OF_GYRATION     0.413509     0.846070              0.134185
# SKEWNESS_ABOUT_MAJOR          0.784997     0.779555              0.165294
# SKEWNESS_ABOUT_MINOR          0.272074     0.249287              0.108713
# KURTOSIS_ABOUT_MAJOR          0.123209    -0.132250              0.225742
# KURTOSIS_ABOUT_MINOR          0.956578     0.768875              0.433941
# HOLLOWS_RATIO                 0.952602     0.770437              0.467839
# Class                         0.398998     0.282493              0.483172
#
#                            RADIUS_RATIO  PR.AXIS_ASPECT_RATIO  \
# COMPACTNESS                    0.400849              0.759390
# CIRCULARITY                    0.195790              0.669136
# DISTANCE_CIRCULARITY           0.374063              0.345177
# RADIUS_RATIO                   1.000000              0.755715
# PR.AXIS_ASPECT_RATIO           0.755715              1.000000
# MAX.LENGTH_ASPECT_RATIO        0.459670              0.456668
# SCATTER_RATIO                  0.115224              0.471461
# ELONGATEDNESS                  0.325505              0.798390
# PR.AXIS_RECTANGULARITY         0.284044              0.753220
# MAX.LENGTH_RECTANGULARITY      0.268991              0.748791
# SCALED_VARIANCE_MAJOR          0.516646              0.811261
# SCALED_VARIANCE_MINOR         -0.471274             -0.881894
# SCALED_RADIUS_OF_GYRATION     -0.008700              0.429622
# SKEWNESS_ABOUT_MAJOR           0.207141              0.764559
# SKEWNESS_ABOUT_MINOR           0.043742              0.123334
# KURTOSIS_ABOUT_MAJOR           0.088581              0.063016
# KURTOSIS_ABOUT_MINOR           0.457584              0.831396
# HOLLOWS_RATIO                  0.470026              0.832836
# Class                          0.149951              0.196977
#
#                            MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# COMPACTNESS                               0.104847       0.640513
# CIRCULARITY                               0.182644       0.591633
# DISTANCE_CIRCULARITY                      0.212226       0.463832
# RADIUS_RATIO                              0.459670       0.115224
# PR.AXIS_ASPECT_RATIO                      0.456668       0.471461
# MAX.LENGTH_ASPECT_RATIO                   1.000000      -0.049617
# SCATTER_RATIO                            -0.049617       1.000000
# ELONGATEDNESS                             0.128146       0.650276
# PR.AXIS_RECTANGULARITY                    0.084389       0.799571
# MAX.LENGTH_RECTANGULARITY                 0.210872       0.682032
# SCALED_VARIANCE_MAJOR                     0.414473       0.625389
# SCALED_VARIANCE_MINOR                    -0.245298      -0.615370
# SCALED_RADIUS_OF_GYRATION                 0.118122       0.375559
# SKEWNESS_ABOUT_MAJOR                      0.240268       0.670442
# SKEWNESS_ABOUT_MINOR                      0.001626       0.058091
# KURTOSIS_ABOUT_MAJOR                      0.009674       0.177629
# KURTOSIS_ABOUT_MINOR                      0.119813       0.690107
# HOLLOWS_RATIO                             0.140912       0.691948
# Class                                     0.284606       0.080263
#
#                            ELONGATEDNESS  PR.AXIS_RECTANGULARITY  \
# COMPACTNESS                     0.937812                0.917570
# CIRCULARITY                     0.800523                0.795252
# DISTANCE_CIRCULARITY            0.336962                0.408667
# RADIUS_RATIO                    0.325505                0.284044
# PR.AXIS_ASPECT_RATIO            0.798390                0.753220
# MAX.LENGTH_ASPECT_RATIO         0.128146                0.084389
# SCATTER_RATIO                   0.650276                0.799571
# ELONGATEDNESS                   1.000000                0.964112
# PR.AXIS_RECTANGULARITY          0.964112                1.000000
# MAX.LENGTH_RECTANGULARITY       0.905596                0.905695
# SCALED_VARIANCE_MAJOR           0.743204                0.751170
# SCALED_VARIANCE_MINOR          -0.976870               -0.935921
# SCALED_RADIUS_OF_GYRATION       0.522214                0.513156
# SKEWNESS_ABOUT_MAJOR            0.901338                0.888216
# SKEWNESS_ABOUT_MINOR            0.222700                0.191050
# KURTOSIS_ABOUT_MAJOR            0.135106                0.154812
# KURTOSIS_ABOUT_MINOR            0.968493                0.952784
# HOLLOWS_RATIO                   0.962715                0.949719
# Class                           0.312672                0.281216
#
#                            MAX.LENGTH_RECTANGULARITY  SCALED_VARIANCE_MAJOR  \
# COMPACTNESS                                 0.865361               0.703115
# CIRCULARITY                                 0.952353               0.601254
# DISTANCE_CIRCULARITY                        0.428002               0.376476
# RADIUS_RATIO                                0.268991               0.516646
# PR.AXIS_ASPECT_RATIO                        0.748791               0.811261
# MAX.LENGTH_ASPECT_RATIO                     0.210872               0.414473
# SCATTER_RATIO                               0.682032               0.625389
# ELONGATEDNESS                               0.905596               0.743204
# PR.AXIS_RECTANGULARITY                      0.905695               0.751170
# MAX.LENGTH_RECTANGULARITY                   1.000000               0.694462
# SCALED_VARIANCE_MAJOR                       0.694462               1.000000
# SCALED_VARIANCE_MINOR                      -0.922535              -0.805838
# SCALED_RADIUS_OF_GYRATION                   0.704570               0.419952
# SKEWNESS_ABOUT_MAJOR                        0.845687               0.810669
# SKEWNESS_ABOUT_MINOR                        0.227206               0.051249
# KURTOSIS_ABOUT_MAJOR                       -0.005951               0.116758
# KURTOSIS_ABOUT_MINOR                        0.888207               0.769727
# HOLLOWS_RATIO                               0.890988               0.757912
# Class                                       0.368309               0.117354
#
#                            SCALED_VARIANCE_MINOR  SCALED_RADIUS_OF_GYRATION  \
# COMPACTNESS                            -0.934506                   0.413509
# CIRCULARITY                            -0.831637                   0.846070
# DISTANCE_CIRCULARITY                   -0.400163                   0.134185
# RADIUS_RATIO                           -0.471274                  -0.008700
# PR.AXIS_ASPECT_RATIO                   -0.881894                   0.429622
# MAX.LENGTH_ASPECT_RATIO                -0.245298                   0.118122
# SCATTER_RATIO                          -0.615370                   0.375559
# ELONGATEDNESS                          -0.976870                   0.522214
# PR.AXIS_RECTANGULARITY                 -0.935921                   0.513156
# MAX.LENGTH_RECTANGULARITY              -0.922535                   0.704570
# SCALED_VARIANCE_MAJOR                  -0.805838                   0.419952
# SCALED_VARIANCE_MINOR                   1.000000                  -0.564404
# SCALED_RADIUS_OF_GYRATION              -0.564404                   1.000000
# SKEWNESS_ABOUT_MAJOR                   -0.878631                   0.613846
# SKEWNESS_ABOUT_MINOR                   -0.230599                   0.255430
# KURTOSIS_ABOUT_MAJOR                   -0.098629                  -0.257035
# KURTOSIS_ABOUT_MINOR                   -0.975574                   0.454569
# HOLLOWS_RATIO                          -0.973233                   0.448892
# Class                                  -0.325911                   0.099474
#
#                            SKEWNESS_ABOUT_MAJOR  SKEWNESS_ABOUT_MINOR  \
# COMPACTNESS                            0.784997              0.272074
# CIRCULARITY                            0.779555              0.249287
# DISTANCE_CIRCULARITY                   0.165294              0.108713
# RADIUS_RATIO                           0.207141              0.043742
# PR.AXIS_ASPECT_RATIO                   0.764559              0.123334
# MAX.LENGTH_ASPECT_RATIO                0.240268              0.001626
# SCATTER_RATIO                          0.670442              0.058091
# ELONGATEDNESS                          0.901338              0.222700
# PR.AXIS_RECTANGULARITY                 0.888216              0.191050
# MAX.LENGTH_RECTANGULARITY              0.845687              0.227206
# SCALED_VARIANCE_MAJOR                  0.810669              0.051249
# SCALED_VARIANCE_MINOR                 -0.878631             -0.230599
# SCALED_RADIUS_OF_GYRATION              0.613846              0.255430
# SKEWNESS_ABOUT_MAJOR                   1.000000              0.149154
# SKEWNESS_ABOUT_MINOR                   0.149154              1.000000
# KURTOSIS_ABOUT_MAJOR                   0.064093             -0.040529
# KURTOSIS_ABOUT_MINOR                   0.823563              0.218858
# HOLLOWS_RATIO                          0.807729              0.213331
# Class                                  0.152044              0.206252
#
#                            KURTOSIS_ABOUT_MAJOR  KURTOSIS_ABOUT_MINOR  \
# COMPACTNESS                            0.123209              0.956578
# CIRCULARITY                           -0.132250              0.768875
# DISTANCE_CIRCULARITY                   0.225742              0.433941
# RADIUS_RATIO                           0.088581              0.457584
# PR.AXIS_ASPECT_RATIO                   0.063016              0.831396
# MAX.LENGTH_ASPECT_RATIO                0.009674              0.119813
# SCATTER_RATIO                          0.177629              0.690107
# ELONGATEDNESS                          0.135106              0.968493
# PR.AXIS_RECTANGULARITY                 0.154812              0.952784
# MAX.LENGTH_RECTANGULARITY             -0.005951              0.888207
# SCALED_VARIANCE_MAJOR                  0.116758              0.769727
# SCALED_VARIANCE_MINOR                 -0.098629             -0.975574
# SCALED_RADIUS_OF_GYRATION             -0.257035              0.454569
# SKEWNESS_ABOUT_MAJOR                   0.064093              0.823563
# SKEWNESS_ABOUT_MINOR                  -0.040529              0.218858
# KURTOSIS_ABOUT_MAJOR                   1.000000              0.142133
# KURTOSIS_ABOUT_MINOR                   0.142133              1.000000
# HOLLOWS_RATIO                          0.160590              0.997155
# Class                                  0.071953              0.294455
#
#                            HOLLOWS_RATIO     Class
# COMPACTNESS                     0.952602  0.398998
# CIRCULARITY                     0.770437  0.282493
# DISTANCE_CIRCULARITY            0.467839  0.483172
# RADIUS_RATIO                    0.470026  0.149951
# PR.AXIS_ASPECT_RATIO            0.832836  0.196977
# MAX.LENGTH_ASPECT_RATIO         0.140912  0.284606
# SCATTER_RATIO                   0.691948  0.080263
# ELONGATEDNESS                   0.962715  0.312672
# PR.AXIS_RECTANGULARITY          0.949719  0.281216
# MAX.LENGTH_RECTANGULARITY       0.890988  0.368309
# SCALED_VARIANCE_MAJOR           0.757912  0.117354
# SCALED_VARIANCE_MINOR          -0.973233 -0.325911
# SCALED_RADIUS_OF_GYRATION       0.448892  0.099474
# SKEWNESS_ABOUT_MAJOR            0.807729  0.152044
# SKEWNESS_ABOUT_MINOR            0.213331  0.206252
# KURTOSIS_ABOUT_MAJOR            0.160590  0.071953
# KURTOSIS_ABOUT_MINOR            0.997155  0.294455
# HOLLOWS_RATIO                   1.000000  0.328864
# Class                           0.328864  1.000000

# %%
sns.heatmap(df_ready.corr());

# %%
## part d:

# %%
y = df_ready['Class']

# %%
x = df_ready.drop(['Class'], axis=1)

# %%
## part e:

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

# %%
y_train.value_counts()
# Out:
# 2.0    184
# 1.0    172
# 0.0    169
# 3.0    151
# Name: Class, dtype: int64

# %%
y_test.value_counts()
# Out:
# 0.0    49
# 3.0    48
# 1.0    40
# 2.0    33
# Name: Class, dtype: int64

# %%
## part f:

# %%
import statsmodels.tools.tools as stattools
from sklearn.tree import DecisionTreeClassifier, export_graphviz

# %%
c50_01 = DecisionTreeClassifier(criterion="entropy", max_leaf_nodes=6).fit(x_train,y_train)

# %%
from sklearn import tree

# %%
tree.plot_tree(c50_01);

# %%
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(1, 1, figsize=(15, 15))
tree.plot_tree(c50_01, ax=axes);

# %%
## part g:

# %%
y_pred = c50_01.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[44  0  4  1]
#  [ 1  0 31  8]
#  [ 0  0 29  4]
#  [ 5  0  0 43]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89        49
#          1.0       0.00      0.00      0.00        40
#          2.0       0.45      0.88      0.60        33
#          3.0       0.77      0.90      0.83        48
#
#     accuracy                           0.68       170
#    macro avg       0.53      0.67      0.58       170
# weighted avg       0.56      0.68      0.61       170
# C:\Users\Marzieh\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Marzieh\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Marzieh\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
## part i:

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
clf = c50_01.fit(iris.data, iris.target)

# %%
dot_file = open("Desktop/dot_file.dot", 'w')
tree.export_graphviz(clf, out_file = dot_file)
dot_file.close()
dot_file
# Out:
# <_io.TextIOWrapper name='Desktop/dot_file.dot' mode='w' encoding='cp1256'>

# %%
from IPython.display import Image
from sklearn.tree import export_graphviz
from pydotplus import graph_from_dot_data
from graphviz import Source

# %%
Source.from_file("Desktop/dot_file.dot")
