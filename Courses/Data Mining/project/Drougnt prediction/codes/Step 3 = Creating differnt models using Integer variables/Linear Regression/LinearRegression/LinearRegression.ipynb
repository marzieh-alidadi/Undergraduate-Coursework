# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn import metrics

# %% [markdown]
# # **Train:**

# %% [markdown]
# Normalize:

# %%
df_Normalized = pd.read_csv('D:\DM project\Step 2 = normalizing datasets with two ways\output_datasets\Train_Normalized.csv')

# %% [markdown]
# correlation of normalized dataframe:

# %%
df_Normalized.corr()
# Out:
#                  fips   PRECTOT        PS      QV2M       T2M    T2MDEW  \
# fips         1.000000 -0.012617  0.041012 -0.050903 -0.043224 -0.042813
# PRECTOT     -0.012617  1.000000 -0.163654  0.223343  0.060147  0.210059
# PS           0.041012 -0.163654  1.000000 -0.800718 -0.794927 -0.699961
# QV2M        -0.050903  0.223343 -0.800718  1.000000  0.847060  0.951367
# T2M         -0.043224  0.060147 -0.794927  0.847060  1.000000  0.894924
# T2MDEW      -0.042813  0.210059 -0.699961  0.951367  0.894924  1.000000
# T2MWET      -0.043025  0.209890 -0.702344  0.952446  0.895788  0.999965
# T2M_MAX     -0.044975 -0.017499 -0.765761  0.760816  0.977075  0.814536
# T2M_MIN     -0.041489  0.118876 -0.780740  0.892262  0.977535  0.930806
# T2M_RANGE   -0.014310 -0.329070 -0.065545 -0.214161  0.128322 -0.170683
# TS          -0.038879  0.057283 -0.797164  0.837992  0.996880  0.886478
# WS10M        0.047728  0.024474  0.140098 -0.340113 -0.299848 -0.344856
# ...

# %% [markdown]
# StandardScaler:

# %%
df_StandardScalered = pd.read_csv('D:\DM project\Step 2 = normalizing datasets with two ways\output_datasets\Train_StandardScalered.csv')

# %% [markdown]
# correlation of StandardScalered dataframe:

# %%
df_StandardScalered.corr()
# Out:
#                  fips   PRECTOT        PS      QV2M       T2M    T2MDEW  \
# fips         1.000000 -0.012617  0.041012 -0.050903 -0.043224 -0.042813
# PRECTOT     -0.012617  1.000000 -0.163654  0.223343  0.060147  0.210059
# PS           0.041012 -0.163654  1.000000 -0.800718 -0.794927 -0.699961
# QV2M        -0.050903  0.223343 -0.800718  1.000000  0.847060  0.951367
# T2M         -0.043224  0.060147 -0.794927  0.847060  1.000000  0.894924
# T2MDEW      -0.042813  0.210059 -0.699961  0.951367  0.894924  1.000000
# T2MWET      -0.043025  0.209890 -0.702344  0.952446  0.895788  0.999965
# T2M_MAX     -0.044975 -0.017499 -0.765761  0.760816  0.977075  0.814536
# T2M_MIN     -0.041489  0.118876 -0.780740  0.892262  0.977535  0.930806
# T2M_RANGE   -0.014310 -0.329070 -0.065545 -0.214161  0.128322 -0.170683
# TS          -0.038879  0.057283 -0.797164  0.837992  0.996880  0.886478
# WS10M        0.047728  0.024474  0.140098 -0.340113 -0.299848 -0.344856
# ...

# %% [markdown]
# # LinearRegression on Train

# %% [markdown]
# Linear Regression on df_Normalized with all linear attributes:

# %%
X_Normalized = pd.DataFrame(df_Normalized[['PRECTOT', 'PS', 'QV2M', 'T2M', 'T2MDEW', 'T2MWET', 'T2M_MAX', 'T2M_MIN', 'T2M_RANGE', 'TS', 'WS10M', 'WS10M_MAX', 'WS10M_MIN', 'WS10M_RANGE', 'WS50M', 'WS50M_MAX', 'WS50M_MIN', 'WS50M_RANGE']])
y_Normalized = pd.DataFrame(df_Normalized[['score']])

linearModel_Normalized_1 = LinearRegression().fit(X_Normalized, y_Normalized)

# %% [markdown]
# Linear Regression on df_StandardScalered with all linear attributes:

# %%
X_StandardScalered = pd.DataFrame(df_StandardScalered[['PRECTOT', 'PS', 'QV2M', 'T2M', 'T2MDEW', 'T2MWET', 'T2M_MAX', 'T2M_MIN', 'T2M_RANGE', 'TS', 'WS10M', 'WS10M_MAX', 'WS10M_MIN', 'WS10M_RANGE', 'WS50M', 'WS50M_MAX', 'WS50M_MIN', 'WS50M_RANGE']])
y_StandardScalered = pd.DataFrame(df_StandardScalered[['score']])

linearModel_StandardScalered_1 = LinearRegression().fit(X_StandardScalered, y_StandardScalered)

# %% [markdown]
# Linear Regression on df_Normalized with attributes that have corr more than |0.06|

# %%
X_Normalized = pd.DataFrame(df_Normalized[['PRECTOT', 'PS', 'T2M', 'T2MDEW', 'T2MWET', 'T2M_MAX', 'T2M_RANGE', 'TS', 'WS10M_RANGE', 'WS50M_RANGE']])
y_Normalized = pd.DataFrame(df_Normalized[['score']])

linearModel_Normalized_2 = LinearRegression().fit(X_Normalized, y_Normalized)

# %% [markdown]
# Linear Regression on df_StandardScalered with attributes that have corr more than |0.06|

# %%
X_StandardScalered = pd.DataFrame(df_StandardScalered[['PRECTOT', 'PS', 'T2M', 'T2MDEW', 'T2MWET', 'T2M_MAX', 'T2M_RANGE', 'TS', 'WS10M_RANGE', 'WS50M_RANGE']])
y_StandardScalered = pd.DataFrame(df_StandardScalered[['score']])

linearModel_StandardScalered_2 = LinearRegression().fit(X_StandardScalered, y_StandardScalered)

# %% [markdown]
# # **Test:**

# %% [markdown]
# Normalize:

# %%
test_Normalized = pd.read_csv('D:\DM project\Step 2 = normalizing datasets with two ways\output_datasets\Test_Normalized.csv')

# %% [markdown]
# StandardScalere:

# %%
test_StandardScalered = pd.read_csv('D:\DM project\Step 2 = normalizing datasets with two ways\output_datasets\Test_StandardScalered.csv')

# %% [markdown]
# # LinearRegression on Test

# %% [markdown]
# Linear Regression on test_Normalized with all linear attributes:

# %%
X_test_Normalized = pd.DataFrame(test_Normalized[['PRECTOT', 'PS', 'QV2M', 'T2M', 'T2MDEW', 'T2MWET', 'T2M_MAX', 'T2M_MIN', 'T2M_RANGE', 'TS', 'WS10M', 'WS10M_MAX', 'WS10M_MIN', 'WS10M_RANGE', 'WS50M', 'WS50M_MAX', 'WS50M_MIN', 'WS50M_RANGE']])
y_test_Normalized = pd.DataFrame(test_Normalized[['score']])

Y_test_predict_Normalized_1 = linearModel_Normalized_1.predict(X_test_Normalized)

print("MSE:",metrics.mean_squared_error(y_test_Normalized,Y_test_predict_Normalized_1))
print("MAE:",metrics.mean_absolute_error(y_test_Normalized,Y_test_predict_Normalized_1))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test_Normalized,Y_test_predict_Normalized_1)))
print("R_squared:",r2_score(y_test_Normalized,Y_test_predict_Normalized_1))
# Out:
# MSE: 1.329651564799094
# MAE: 0.8858716238465723
# RMSE: 1.1531051837534572
# R_squared: 0.11209029978338181

# %% [markdown]
# Linear Regression on test_StandardScalered with all linear attributes:

# %%
X_test_StandardScalered = pd.DataFrame(test_StandardScalered[['PRECTOT', 'PS', 'QV2M', 'T2M', 'T2MDEW', 'T2MWET', 'T2M_MAX', 'T2M_MIN', 'T2M_RANGE', 'TS', 'WS10M', 'WS10M_MAX', 'WS10M_MIN', 'WS10M_RANGE', 'WS50M', 'WS50M_MAX', 'WS50M_MIN', 'WS50M_RANGE']])
y_test_StandardScalered = pd.DataFrame(test_StandardScalered[['score']])

Y_test_predict_StandardScalered_1 = linearModel_StandardScalered_1.predict(X_test_StandardScalered)

print("MSE:",metrics.mean_squared_error(y_test_StandardScalered,Y_test_predict_StandardScalered_1))
print("MAE:",metrics.mean_absolute_error(y_test_StandardScalered,Y_test_predict_StandardScalered_1))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test_StandardScalered,Y_test_predict_StandardScalered_1)))
print("R_squared:",r2_score(y_test_StandardScalered,Y_test_predict_StandardScalered_1))
# Out:
# MSE: 1.329651564799094
# MAE: 0.8858716238465723
# RMSE: 1.1531051837534572
# R_squared: 0.11209029978338181

# %% [markdown]
# Linear Regression on test_Normalized with attributes that have corr more than |0.06|

# %%
X_test_Normalized = pd.DataFrame(test_Normalized[['PRECTOT', 'PS', 'T2M', 'T2MDEW', 'T2MWET', 'T2M_MAX', 'T2M_RANGE', 'TS', 'WS10M_RANGE', 'WS50M_RANGE']])
y_test_Normalized = pd.DataFrame(test_Normalized[['score']])

Y_test_predict_Normalized_2 = linearModel_Normalized_2.predict(X_test_Normalized)

print("MSE:",metrics.mean_squared_error(y_test_Normalized,Y_test_predict_Normalized_2))
print("MAE:",metrics.mean_absolute_error(y_test_Normalized,Y_test_predict_Normalized_2))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test_Normalized,Y_test_predict_Normalized_2)))
print("R_squared:",r2_score(y_test_Normalized,Y_test_predict_Normalized_2))
# Out:
# MSE: 1.3353193932602092
# MAE: 0.8784102828186104
# RMSE: 1.155560207544466
# R_squared: 0.10830545869943331

# %% [markdown]
# Linear Regression on test_StandardScalered with attributes that have corr more than |0.06|

# %%
X_test_StandardScalered = pd.DataFrame(test_StandardScalered[['PRECTOT', 'PS', 'T2M', 'T2MDEW', 'T2MWET', 'T2M_MAX', 'T2M_RANGE', 'TS', 'WS10M_RANGE', 'WS50M_RANGE']])
y_test_StandardScalered = pd.DataFrame(test_StandardScalered[['score']])

Y_test_predict_StandardScalered_2 = linearModel_StandardScalered_2.predict(X_test_StandardScalered)

print("MSE:",metrics.mean_squared_error(y_test_StandardScalered,Y_test_predict_StandardScalered_2))
print("MAE:",metrics.mean_absolute_error(y_test_StandardScalered,Y_test_predict_StandardScalered_2))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test_StandardScalered,Y_test_predict_StandardScalered_2)))
print("R_squared:",r2_score(y_test_StandardScalered,Y_test_predict_StandardScalered_2))
# Out:
# MSE: 1.3353193932602092
# MAE: 0.8784102828186104
# RMSE: 1.155560207544466
# R_squared: 0.10830545869943331
